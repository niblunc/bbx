# %% [markdown]
# # Scan Notes

# %%
import os, glob
from IPython.core import display as ICD
import pandas as pd

pd.set_option('display.max_rows', 159)
pd.set_option('display.max_colwidth', -1)

# %%
# get scan notes
notes_path=os.path.join('w1_notes.csv')
s1_notes=pd.read_csv(notes_path, encoding='latin-1')
#df_w1_notes.head()
#df_w1_notes.columns
s1_notes_clean=s1_notes[['participantID', 'w1scan_scannotes']]

s1_notes_clean.set_index("participantID", inplace=True)
s1_notes_clean.index = s1_notes_clean.index.str.lower()
s1_notes_clean = s1_notes_clean.drop(['participant id (bbx_###)'])

# %% [markdown]
# ## Session 1 Notes:

# %%
s1_notes_clean
# Out:
#                                                                                                                                                                                                                                                                                                                      w1scan_scannotes
# participantID
# bbx_001        NaN
# bbx_002        NaN
# bbx_005        NaN
# bbx_004        NaN
# bbx_006        NaN
# bbx_007        NaN
# bbx_008        NaN
# bbx_009        NaN
# bbx_011        NaN
# bbx_003        NaN
# bbx_010        NaN
# bbx_012        Good, pretty stilll
# bbx_013        Good, very little motion
# bbx_015        Good, a little motion
# bbx_014        Great job staying still
# bbx_016        Great job staying still
# bbx_021        Good
# bbx_019        Great job staying still
# bbx_017        Great job staying still
# bbx_023        Did really well staying still despite feeling sick/having a cold
# ...
