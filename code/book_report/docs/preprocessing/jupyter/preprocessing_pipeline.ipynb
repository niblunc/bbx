# %% [markdown]
# # Preprocessing Pipeline
#
# ## TOC:
# * [BIDS](#bids)
# * [FMRIPREP](#fmriprep)
# * [SKULL STRIPPING](#skull)
# * [VOLUME TRIM](#vol)
# * [CONFOUND MOTION CORRECTION PARAMETERS PULL](#mocos)
# * [CONFOUND OUTLIER SETUP](#outliers)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (20,15)

# %% [markdown]
# ---
# ## Trim Volumes
# ---
# Using the `fslroi` command to trim volumes from a file. For the BBX dataset, we cut the first 4 volumes from the nifti images.
# We submit a batch job that excutes on an array of given subjects.
#
# [GITHUB CODE]()

# %% [markdown]
# ---
# ## Prepare Confounds
# ---

# %% [markdown]
# ### Basic Confounds
# FMRIPREP provides outputs, `_regressors.tsv` files, that
# The **estimated head-motion parameters**: `trans_x`, `trans_y`, `trans_z`, `rot_x`, `rot_y`, `rot_z`
# These are the 6 rigid-body motion parameters (3 translations and 3 rotation), estimated relative to a reference image.
#
# For BBX, the first 4 volumes in the nifti image were trimmed; **therefore the first 4 timepoints in the confound files have to be removed.**

# %% [markdown]
# ### Spike Regressors

# %% [markdown]
# ## Timing Files (Onsets)
# ---

# %% [markdown]
# **Quick Statistics**

# %% [markdown]
# **Quality Report**

# %% [markdown]
# ## Feat1

# %%
design1_sample='/Users/nikkibytes/Documents/git_nibl/bbx/design.png'

print('[INFO] feat1 cope design(.png)')
img = mpimg.imread(design1_sample)
imgplot = plt.imshow(img)
plt.show()
# Out:
# [INFO] feat1 cope design(.png)
