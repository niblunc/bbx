# %%
"""
@author: NTA, at NIBL
The module is used to parse log files from the bbx experiment
"""
import os, glob
import pandas as pd
from IPython.display import display



# Module
class OnsetSetup():

    def __init__(self, folder_path):
        self.folder_path=folder_path
        self.onset_dict={}

    def get_files(self):
        log_file_list=glob.glob(os.path.join(self.folder_path, "*.log"))
        log_file_list.sort()
        return log_file_list;

    def load_file(self, file, output_path):
        sub_id=file.split('/')[-1].split("_")[1]
        run=file.split('/')[-1].split("_")[2].split("0")[1]
        wave=file.split('/')[-1].split("_")[3]

        if "pre" in wave or "post" in wave:
            if "post" in wave:
                ses = 'ses-2'
            if wave == "pre":
                ses = 'ses-1'
            #print(sub_id, run, ses)


            df=pd.read_csv(file, sep="\t", header=None)
            df.columns =["time", "data", "keypress"]

            # Set Start time dataframes
            #print("[INFO] querying start time....")
            st_query=df[df['data'].str.contains('Level start key press')]
            #display(st_query)
            start_time=float(st_query['time'])
            #print('[INFO] start time: ', start_time)

            
            
            
            # SSB CUE
            # The SSB cues are  either "C0" or "SL"
            # -- no one will receive both
            ######################################################
            ssb_cue_query=df[(df["data"].str.contains("image=CO.jpg")) | 
                                  (df["data"].str.contains("image=SL.jpg"))]
            #print("[INFO] ssb cue logfile query: ", ssb_cue_query)
            
            ssb_cue_query= ssb_cue_query.drop(["data", "keypress"], axis=1)
            # add stim time and mod column
            ssb_cue_query["stim"] = 1
            ssb_cue_query["mod"] = 1
            
            ssb_cue_query.time -=  start_time
            
            ssb_cue_query.reset_index(inplace=True, drop=True)
            
            #print("[INFO] ssb cue onset setup: \n", ssb_cue_query)

            ssb_cue_tsv = os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt" % (sub_id, ses, "SSBcue", run))
            
            #print('[INFO] SSBcue: ', ssb_cue_tsv)
            ssb_cue_query.to_csv(ssb_cue_tsv, sep="\t", index=False, header=False)

            
            #print("--------------------------------------\n")

            # SSB taste 
            ######################################################

            ssb_taste_query = df[df["data"].str.contains("Level post injecting via pump at address 1")]
            ssb_taste_query = ssb_taste_query.drop(["data", "keypress"], axis=1)
            #print("[INFO] ssb taste logfile query: ", ssb_taste_query)
            # add stim time and mod column
            ssb_taste_query["stim"] = 6
            ssb_taste_query["mod"] = 1
            # subtract start time
            ssb_taste_query.time -= start_time# subtract start time
            ssb_taste_query.reset_index(inplace=True, drop=True)
            #print("[INFO] ssb taste onset setup: \n", ssb_taste_query)
            ssb_taste_tsv = os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt" % (sub_id, ses, "SSBtaste", run))
            #print('[INFO] SSBtaste: ', ssb_taste_tsv)
            ssb_taste_query.to_csv(ssb_taste_tsv, sep="\t", index=False, header=False)
            #print("--------------------------------------\n")
            
            
            # USB cue
            ######################################################
            usb_cue_query = df[(df["data"].str.contains("image=UCO.jpg")) | (df["data"].str.contains("image=USL.jpg"))]
            usb_cue_query = usb_cue_query.drop(["data", "keypress"], axis=1)
            # add stim time and mod column
            usb_cue_query["stim"] = 1
            usb_cue_query["mod"] = 1
            usb_cue_query.time -= start_time # subtract start time
            usb_cue_query.reset_index(inplace=True, drop=True)
            #print("[INFO] usb cue onset setup: \n", usb_cue_query)
            usb_cue_tsv = os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt" % (sub_id, ses, "USBcue", run))
            #print('[INFO] USBcue: ',usb_cue_tsv)
            usb_cue_query.to_csv(usb_cue_tsv, sep="\t", index=False, header=False)
            #print("--------------------------------------\n")
            
            
            
            # USB taste
            ######################################################
            usb_taste_query = df[df["data"].str.contains("Level post injecting via pump at address 2")]
            usb_taste_query = usb_taste_query.drop(["data", "keypress"], axis=1)
            # add stim time and mod column
            usb_taste_query["stim"] = 6
            usb_taste_query["mod"] = 1
            usb_taste_query.time -= start_time# subtract start time
            usb_taste_query.reset_index(inplace=True, drop=True)
            #print("[INFO] usb taste onset setup: \n", usb_taste_query)
            usb_taste_tsv = os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt" % (sub_id, ses, "USBtaste", run))
            #print('[INFO] USB taste: ',usb_taste_tsv)
            usb_taste_query.to_csv(usb_taste_tsv, sep="\t", index=False, header=False)
            #print("--------------------------------------\n")
            
            
            # Water cue
            ######################################################
            h2O_cue_query = df[(df["data"].str.contains("image=water.jpg"))]
            h2O_cue_query = h2O_cue_query.drop(["data", "keypress"], axis=1)
            # add stim time and mod column
            h2O_cue_query["stim"] = 1
            h2O_cue_query["mod"] = 1
            h2O_cue_query.time -= start_time # subtract start time
            h2O_cue_query.reset_index(inplace=True, drop=True)
            #print("[INFO] h2O cue onset setup: \n", h2O_cue_query)
            h2O_cue_tsv = os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt" % (sub_id, ses, "h2Ocue", run))
            #print('[INFO] h2O cue: ',h2O_cue_tsv)
            h2O_cue_query.to_csv(h2O_cue_tsv, sep="\t", index=False, header=False)
            #print("--------------------------------------\n")
            

            # Water taste
            ######################################################
            h2O_taste_query = df[df["data"].str.contains("Level post injecting via pump at address 0")]
            h2O_taste_query = h2O_taste_query.drop(["data", "keypress"], axis=1)
            # add stim time and mod column
            h2O_taste_query["stim"] = 6
            h2O_taste_query["mod"] = 1
            h2O_taste_query.time -= start_time# subtract start time
            h2O_taste_query.reset_index(inplace=True, drop=True)
            #print("[INFO] h2O taste onset setup: \n", h2O_taste_query)
            h2O_taste_tsv = os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt" % (sub_id, ses, "h2Otaste", run))
            #print('[INFO] h2O taste: ',h2O_taste_tsv)
            h2O_taste_query.to_csv(h2O_taste_tsv, sep="\t", index=False, header=False)
            #print("--------------------------------------\n")
            
            
            # Neutral ~ rinse
            ######################################################
            neu_query = df[(df["data"].str.contains("Level RINSE"))]
            neu_query = neu_query.drop(["data", "keypress"], axis=1)
            # add stim time and mod column
            neu_query["stim"]=3
            neu_query["mod"] = 1
            neu_query.time -= start_time# subtract start time
            neu_query.reset_index(inplace=True, drop=True)
            #print("[INFO] rinse onset setup: \n", neu_query)
            # write to file
            neu_tsv=os.path.join(output_path, "sub-%s_%s_task-%s_run-%s.txt"%(sub_id, ses, "neu", run))
            #print('[INFO] neutral/rinse: ',neu_tsv)
            neu_query.to_csv(neu_tsv, sep="\t", index=False, header=False)

            #print("--------------------------------------\n")
            
        else:
            pass

# %%
# Test Cases

def test_data_grab(obj):
    log_files=obj.get_files()
    #print("[INFO] found %s log files. \n %s"%(len(log_files), log_files[:3]))
    return log_files;

def test_file_load(obj, log_files):
    
    for file in log_files:
        obj.load_file(file, output_path)

print("[INFO] starting onset file generator....")
data_folder="/Users/nikkibytes/Documents/local_dev/bbx/log_files"
output_path='/Users/nikkibytes/Documents/local_dev/bbx/output_onsets'
obj=OnsetSetup(data_folder)
log_files=test_data_grab(obj)
test_file_load(obj, log_files)
print("[INFO] finished process.")
# Out:
# [INFO] starting onset file generator....
# [INFO] start time:  58.7065
# [INFO] ssb cue onset setup:
#         time  stim  mod
# 0   64.9402     1    1
# 1  121.9564     1    1
# 2  162.9541     1    1
# 3  240.9455     1    1
# 4  306.9474     1    1
# 5  341.9298     1    1
# 6  375.9501     1    1
# 7  413.9505     1    1
# --------------------------------------
#
# [INFO] ssb taste onset setup:
#         time  stim  mod
# 0   65.7353     6    1
# 1  122.7504     6    1
# 2  163.7530     6    1
# 3  241.7577     6    1
# 4  307.7437     6    1
# 5  342.7420     6    1
# 6  376.7465     6    1
# 7  414.7470     6    1
# --------------------------------------
#
# [INFO] usb cue onset setup:
#         time  stim  mod
# 0   46.9287     1    1
# 1  141.9341     1    1
# 2  184.9577     1    1
# 3  256.9440     1    1
# 4  289.9372     1    1
# 5  323.9421     1    1
# 6  357.9453     1    1
# 7  391.9661     1    1
# --------------------------------------
#
# ...

# %%
# Main -- user must run
# set variables and initialize object
if __name__ == "__main__":
    #commandline parser
    parser=argparse.ArgumentParser(description='onset file generator for bbx')
    parser.add_argument('-session', dest='SES', action='store',
			default=False, help='which session are we running on?')
    parser.add_argument('-subject', dest='SUB', action='store',
			default=False, help='which subject to analyze')
    parser.add_argument('-outpath', dest='outpath', action='store_true',
                       default=False, help='output directory path')
    parser.add_argument('-input', dest='input', action='store_true',
			default=False, help='input directory path')
    
    
    args = parser.parse_args()
    arglist={}
   
    for a in args._get_kwargs():
       arglist[a[0]]=a[1]
