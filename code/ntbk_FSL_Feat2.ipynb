# %% [markdown]
# # FSL Feat 2
#
# This notebook is a walkthrough of BBX FSL feat2 analysis, including setup, batch submission, and quality checking.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import glob, os
import subprocess as sp
import pandas as pd
import ipywidgets as widgets

from nilearn import image, plotting
from openpyxl import load_workbook
from shutil import rmtree 

pd.set_option('display.max_rows', 300)
plt.rcParams["figure.figsize"] = (20,15)

# %%
from nilearn import plotting

img='/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-010/ses-1/fsl_feat2/sub-010_ses-1_task-training_19contrasts.gfeat/cope18.feat/stats/zstat1.nii.gz'
fig = plt.figure(figsize=(12, 6))


plotting.plot_glass_brain( img, figure=fig, title='Model 2 Example Result | sub-010 cope18: usbtaste+ssbtaste>rinse, zstat file',
    black_bg=True, display_mode='lyr', threshold=3, cmap='cool')

plotting.show()

# %% [markdown]
# Setup Variables

# %%
study_path="/projects/niblab/experiments/bbx"
sub_ids=[x.split("/")[-1] for x in glob.glob(os.path.join("/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-*"))]
sub_ids.sort()

# %%
less_runs=['sub-060', 'sub-002', 'sub-004', 'sub-031', 'sub-042', 'sub-048', 
           'sub-070', 'sub-073', 'sub-076', 'sub-079', 'sub-117', 'sub-128', 
           'sub-133', 'sub-146', 'sub-147', 'sub-148', 'sub-149', 'sub-156']


remove_subs=['sub-029', 'sub-047', 'sub-049', 'sub-069', 'sub-081', 'sub-094', 'sub-101',
             'sub-105', 'sub-106', 'sub-110', 'sub-113', 'sub-122', 'sub-125', 'sub-126', 
             'sub-139', 'sub-155', 'sub-158', 'sub-165']

s2_drop_subjects=["sub-003", 'sub-012','sub-016', 'sub-018',  "sub-020", "sub-024", "sub-025",'sub-026', 'sub-035',
                  "sub-052", 'sub-056', "sub-059", "sub-060", "sub-064","sub-074", "sub-076", "sub-077", 'sub-087',
                  'sub-108', "sub-147", "sub-150", "sub-167"]

# %% [markdown]
# ## Skipping Registration
#
# When using the FMRIPREP process we skip registration in FSL feat1 because it was already done in the FMRIPREP process. Before running feat2, *we have to modify the feat1 folders slighty to adjust for this registration difference.*
#
# Full run down video: [skipping registration](https://www.youtube.com/watch?v=U3tG7JMEf7M)
#
# * Check for `reg_standard/` folder, delete if it exists.
# Note, this is only created if a feat2 process has been run, should not exist otherwise.
#
#
# * Delete all `.mat` files in the `reg/` folder, replace with identity matrix.
# `cp $FSLDIR/etc/flirtsch/ident.mat reg/ example_func2standard.mat`
# This ensures the data won't be moved at all.
#
#
# * Make sure the data isn't interpolated again.
# Essentially means, after the movement the voxels still align exactly.
# `cp mean_func.nii.gz reg/standard.nii.gz`

# %%
class BBXFeat1Modeling:
    
    
    def __init__(self):
        self.data_path='/projects/niblab/experiments/bbx/data'
    
    def skipping_registration(self, sub_data_path,folder_tag, verbose=False):
        
        if verbose==True: print('[INFO] running skipping reg process for %s'%sub_data_path.split("/")[-2])
        feat_folders=glob.glob(os.path.join(
                sub_data_path, "fsl_feat1/*%s.feat"%folder_tag))

        feat_folders.sort()

        # loop through subject feat1 folders
        for feat_folder in feat_folders:

            # get .mat files for subject
            mat_files = glob.glob(os.path.join(feat_folder, "reg/*.mat"))

            # loop through .mat files found 
            for mat_file in mat_files:        

                if verbose==True: print("\n[INFO] removing .mat files \n%s"%mat_file)

                try:
                    os.remove(mat_file)
                except Exception as e:
                    print(e)

            # Remove reg_standard directories

            reg_std_folder = os.path.join(feat_folder, "reg_standard")# reg_standard/ directories 

            if os.path.exists(reg_std_folder):
                if verbose==True: print("\n[INFO] removing reg_standard/ directory \n%s"%reg_std_folder)

                # remove folder
                try:
                    rmtree(reg_std_folder)

                except Exception as e:
                    print(e)        

            # Copy identity matrix
            reg_folders = glob.glob(os.path.join(sub_data_path, "fsl_feat1/*run*%s.feat/reg"%folder_tag))
            
            for reg in reg_folders:
                path="%s/example_func2standard.mat"%reg
                copy_mat_cmd='cp $FSLDIR/etc/flirtsch/ident.mat %s'%path

                if verbose==True: print("\n[INFO] copying identity matrix \n%s"%copy_mat_cmd)

                try:
                    sp.run(copy_mat_cmd, shell=True)
                except Exception as e:
                    print(e)

            # copy mean files           
            MEAN_PATH = os.path.join(feat_folder, "mean_func.nii.gz")
            REG_DIR = os.path.join(feat_folder, "reg", "standard.nii.gz")

            copy_mean_cmd = 'cp %s %s'%(MEAN_PATH, REG_DIR)
            if verbose==True: print("\n[INFO] copying mean file \n%s"%copy_mean_cmd)
            sp.run(copy_mean_cmd, shell=True)

# %%
obj=BBXFeat1Modeling()
base_path='/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed' 
task="task-training"
session='ses-1'
for sub in sub_ids:
    subject=sub
    subject_path=os.path.join(base_path,subject, session)

    # call the skipping_registration() method
    # subject_path = the preprocessed folder, where feat1 folder is held
    # verbose = True, verbose=False by default
    obj.skipping_registration(subject_path, '19contrasts',False)
    
print('[INFO] process complete.')
# Out:
# [INFO] process complete.

# %% [markdown]
# ---

# %% [markdown]
# ## Make Files -

# %%
def setup_feat2(sub_folder, folder_tag, verbose=True, make_dir=True):
        # set variables
        subject = sub_folder.split("/")[-2]
        session = sub_folder.split("/")[-1]
        filename="%s_%s_task-training_%s"%(subject, session, folder_tag)
        
        #check for existence of feat2 directory
        feat2_path = os.path.join(sub_folder, "fsl_feat2")

        if make_dir==True:
            if os.path.exists(feat2_path):
                #if verbose==True: print('[INFO] path %s already exists'%feat2_path)
                pass
            else:
                os.makedirs(feat2_path)


        # setup variables to fill fsf file

        # get feat1 paths
        feat1_path = os.path.join(sub_folder, "fsl_feat1/*%s.feat"%folder_tag)
        feat1_folders = sorted(glob.glob(feat1_path)) 
        feat1_ct=len(feat1_folders)
        #if verbose==True: print("[INFO] %s feat1 folders found"%feat1_ct)

        if feat1_ct == 4:

            design_file="/projects/niblab/experiments/bbx/data/feat_design_files/model2.fsf"


            # open fsf template file
            with open(os.path.join(design_file), 'r') as infile:
                tempfsf=infile.read()
                # set outpath for fsf OUTPATH variable, by run
                sub_id =  sub_folder.split("/")[-2]
                outpath = os.path.join(feat2_path, 
                       '%s'%(filename))
                print('[INFO] outpath: ', outpath)
                tempfsf = tempfsf.replace("OUTPUT", outpath)

                # fill in feat1 folder paths
                for index,feat_path in enumerate(feat1_folders):
                    feat_id = "run%s"%(index+1)
                    tempfsf = tempfsf.replace(feat_id, feat_path)

                # view fsf file 
                #print("\n\n", tempfsf)

                # setup outfile path for fsf file
                OUTFILE_PATH = os.path.join(feat2_path, "%s.fsf"%(filename))
                #if verbose ==True: print("[INFO] writing to file: ", OUTFILE_PATH)
                # write the new fsf to the fsf file path
                with open(OUTFILE_PATH, "w") as outfile:
                    outfile.write(tempfsf)
                outfile.close()
            infile.close()

        elif feat1_ct==3:
            design_file="/projects/niblab/experiments/bbx/data/feat_design_files/model2.3.fsf"


            # open fsf template file
            with open(os.path.join(design_file), 'r') as infile:
                tempfsf=infile.read()
                # set outpath for fsf OUTPATH variable, by run
                sub_id =  sub_folder.split("/")[-2]
                outpath = os.path.join(feat2_path, 
                       '%s'%(filename))
                #print('[INFO] outpath: ', outpath)
                tempfsf = tempfsf.replace("OUTPUT", outpath)

                # fill in feat1 folder paths
                for index,feat_path in enumerate(feat1_folders):
                    feat_id = "run%s"%(index+1)
                    tempfsf = tempfsf.replace(feat_id, feat_path)

                # view fsf file 
                #print("\n\n", tempfsf)

                # setup outfile path for fsf file
                OUTFILE_PATH = os.path.join(feat2_path, "%s.fsf"%(filename))
                if verbose ==True: print("[INFO] writing to file: ", OUTFILE_PATH)
                # write the new fsf to the fsf file path
                with open(OUTFILE_PATH, "w") as outfile:
                    outfile.write(tempfsf)
                outfile.close()
            infile.close()

        elif feat1_ct==2:
            design_file="/projects/niblab/experiments/bbx/data/feat_design_files/model2.2.fsf"


            # open fsf template file
            with open(os.path.join(design_file), 'r') as infile:
                tempfsf=infile.read()
                
                # set outpath for fsf OUTPATH variable, by run
                sub_id =  sub_folder.split("/")[-2]
                outpath = os.path.join(feat2_path, '%s'%(filename))
                
                #print('[INFO] outpath: ', outpath)
                tempfsf = tempfsf.replace("OUTPUT", outpath)

                # fill in feat1 folder paths
                for index,feat_path in enumerate(feat1_folders):
                    feat_id = "run%s"%(index+1)
                    tempfsf = tempfsf.replace(feat_id, feat_path)

                # setup outfile path for fsf file
                OUTFILE_PATH = os.path.join(feat2_path, "%s.fsf"%(filename))
                if verbose ==True: print("[INFO] writing to file: ", OUTFILE_PATH)
                    
                # write the new fsf to the fsf file path
                with open(OUTFILE_PATH, "w") as outfile:
                    outfile.write(tempfsf)
                outfile.close()
            infile.close()
        else:

            pass

        #if verbose==True: print('[INFO] process complete')

# %%
 sub_ids[:4]
# Out:
# ['sub-001', 'sub-002', 'sub-003', 'sub-004']

# %%
# variables
base_path='/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed' 
task="task-training"
session='ses-1'

for sub in sub_ids:

    subject=sub
    subject_path=os.path.join(base_path,subject, session)
    setup_feat2(subject_path, '19contrasts', verbose=True)
# Out:
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-001/ses-1/fsl_feat2/sub-001_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-002/ses-1/fsl_feat2/sub-002_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-003/ses-1/fsl_feat2/sub-003_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-004/ses-1/fsl_feat2/sub-004_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-005/ses-1/fsl_feat2/sub-005_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-006/ses-1/fsl_feat2/sub-006_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-007/ses-1/fsl_feat2/sub-007_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-008/ses-1/fsl_feat2/sub-008_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-009/ses-1/fsl_feat2/sub-009_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-010/ses-1/fsl_feat2/sub-010_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-011/ses-1/fsl_feat2/sub-011_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-012/ses-1/fsl_feat2/sub-012_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-013/ses-1/fsl_feat2/sub-013_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-014/ses-1/fsl_feat2/sub-014_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-015/ses-1/fsl_feat2/sub-015_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-016/ses-1/fsl_feat2/sub-016_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-017/ses-1/fsl_feat2/sub-017_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-018/ses-1/fsl_feat2/sub-018_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-019/ses-1/fsl_feat2/sub-019_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-020/ses-1/fsl_feat2/sub-020_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-021/ses-1/fsl_feat2/sub-021_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-022/ses-1/fsl_feat2/sub-022_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-023/ses-1/fsl_feat2/sub-023_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-024/ses-1/fsl_feat2/sub-024_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-025/ses-1/fsl_feat2/sub-025_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-026/ses-1/fsl_feat2/sub-026_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-027/ses-1/fsl_feat2/sub-027_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-028/ses-1/fsl_feat2/sub-028_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-030/ses-1/fsl_feat2/sub-030_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-031/ses-1/fsl_feat2/sub-031_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-032/ses-1/fsl_feat2/sub-032_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-033/ses-1/fsl_feat2/sub-033_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-034/ses-1/fsl_feat2/sub-034_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-035/ses-1/fsl_feat2/sub-035_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-036/ses-1/fsl_feat2/sub-036_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-037/ses-1/fsl_feat2/sub-037_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-038/ses-1/fsl_feat2/sub-038_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-039/ses-1/fsl_feat2/sub-039_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-040/ses-1/fsl_feat2/sub-040_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-041/ses-1/fsl_feat2/sub-041_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-042/ses-1/fsl_feat2/sub-042_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-043/ses-1/fsl_feat2/sub-043_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-044/ses-1/fsl_feat2/sub-044_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-045/ses-1/fsl_feat2/sub-045_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-046/ses-1/fsl_feat2/sub-046_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-048/ses-1/fsl_feat2/sub-048_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-050/ses-1/fsl_feat2/sub-050_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-051/ses-1/fsl_feat2/sub-051_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-052/ses-1/fsl_feat2/sub-052_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-053/ses-1/fsl_feat2/sub-053_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-054/ses-1/fsl_feat2/sub-054_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-055/ses-1/fsl_feat2/sub-055_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-056/ses-1/fsl_feat2/sub-056_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-057/ses-1/fsl_feat2/sub-057_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-058/ses-1/fsl_feat2/sub-058_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-059/ses-1/fsl_feat2/sub-059_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-060/ses-1/fsl_feat2/sub-060_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-061/ses-1/fsl_feat2/sub-061_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-062/ses-1/fsl_feat2/sub-062_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-063/ses-1/fsl_feat2/sub-063_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-064/ses-1/fsl_feat2/sub-064_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-065/ses-1/fsl_feat2/sub-065_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-066/ses-1/fsl_feat2/sub-066_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-067/ses-1/fsl_feat2/sub-067_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-068/ses-1/fsl_feat2/sub-068_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-070/ses-1/fsl_feat2/sub-070_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-071/ses-1/fsl_feat2/sub-071_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-072/ses-1/fsl_feat2/sub-072_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-073/ses-1/fsl_feat2/sub-073_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-075/ses-1/fsl_feat2/sub-075_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-076/ses-1/fsl_feat2/sub-076_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-077/ses-1/fsl_feat2/sub-077_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-078/ses-1/fsl_feat2/sub-078_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-079/ses-1/fsl_feat2/sub-079_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-080/ses-1/fsl_feat2/sub-080_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-082/ses-1/fsl_feat2/sub-082_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-083/ses-1/fsl_feat2/sub-083_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-084/ses-1/fsl_feat2/sub-084_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-085/ses-1/fsl_feat2/sub-085_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-086/ses-1/fsl_feat2/sub-086_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-087/ses-1/fsl_feat2/sub-087_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-088/ses-1/fsl_feat2/sub-088_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-089/ses-1/fsl_feat2/sub-089_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-090/ses-1/fsl_feat2/sub-090_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-091/ses-1/fsl_feat2/sub-091_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-092/ses-1/fsl_feat2/sub-092_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-093/ses-1/fsl_feat2/sub-093_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-095/ses-1/fsl_feat2/sub-095_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-096/ses-1/fsl_feat2/sub-096_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-097/ses-1/fsl_feat2/sub-097_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-098/ses-1/fsl_feat2/sub-098_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-099/ses-1/fsl_feat2/sub-099_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-100/ses-1/fsl_feat2/sub-100_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-102/ses-1/fsl_feat2/sub-102_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-103/ses-1/fsl_feat2/sub-103_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-104/ses-1/fsl_feat2/sub-104_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-107/ses-1/fsl_feat2/sub-107_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-109/ses-1/fsl_feat2/sub-109_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-111/ses-1/fsl_feat2/sub-111_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-112/ses-1/fsl_feat2/sub-112_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-114/ses-1/fsl_feat2/sub-114_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-115/ses-1/fsl_feat2/sub-115_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-116/ses-1/fsl_feat2/sub-116_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-117/ses-1/fsl_feat2/sub-117_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-118/ses-1/fsl_feat2/sub-118_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-119/ses-1/fsl_feat2/sub-119_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-120/ses-1/fsl_feat2/sub-120_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-121/ses-1/fsl_feat2/sub-121_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-123/ses-1/fsl_feat2/sub-123_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-124/ses-1/fsl_feat2/sub-124_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-128/ses-1/fsl_feat2/sub-128_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-129/ses-1/fsl_feat2/sub-129_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-130/ses-1/fsl_feat2/sub-130_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-131/ses-1/fsl_feat2/sub-131_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-132/ses-1/fsl_feat2/sub-132_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-133/ses-1/fsl_feat2/sub-133_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-134/ses-1/fsl_feat2/sub-134_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-135/ses-1/fsl_feat2/sub-135_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-136/ses-1/fsl_feat2/sub-136_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-137/ses-1/fsl_feat2/sub-137_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-138/ses-1/fsl_feat2/sub-138_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-140/ses-1/fsl_feat2/sub-140_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-141/ses-1/fsl_feat2/sub-141_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-142/ses-1/fsl_feat2/sub-142_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-143/ses-1/fsl_feat2/sub-143_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-144/ses-1/fsl_feat2/sub-144_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-145/ses-1/fsl_feat2/sub-145_ses-1_task-training_19contrasts
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-146/ses-1/fsl_feat2/sub-146_ses-1_task-training_19contrasts.fsf
# [INFO] writing to file:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-147/ses-1/fsl_feat2/sub-147_ses-1_task-training_19contrasts.fsf
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-148/ses-1/fsl_feat2/sub-148_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-149/ses-1/fsl_feat2/sub-149_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-150/ses-1/fsl_feat2/sub-150_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-151/ses-1/fsl_feat2/sub-151_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-152/ses-1/fsl_feat2/sub-152_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-153/ses-1/fsl_feat2/sub-153_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-154/ses-1/fsl_feat2/sub-154_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-156/ses-1/fsl_feat2/sub-156_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-157/ses-1/fsl_feat2/sub-157_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-159/ses-1/fsl_feat2/sub-159_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-160/ses-1/fsl_feat2/sub-160_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-161/ses-1/fsl_feat2/sub-161_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-162/ses-1/fsl_feat2/sub-162_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-163/ses-1/fsl_feat2/sub-163_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-164/ses-1/fsl_feat2/sub-164_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-166/ses-1/fsl_feat2/sub-166_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-167/ses-1/fsl_feat2/sub-167_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-168/ses-1/fsl_feat2/sub-168_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-169/ses-1/fsl_feat2/sub-169_ses-1_task-training_19contrasts
# [INFO] outpath:  /projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-170/ses-1/fsl_feat2/sub-170_ses-1_task-training_19contrasts

# %% [markdown]
# ## Batch jobs submission

# %%
def run_slurm(start, finish, batch_size, session, file_ext):
    if run_bash == True:
        bash_file = os.path.join('/projects/niblab/experiments/bbx/code/preprocessing/fsl_feat2'
                                 , 'feat2.job')



        #for session in ['ses-1', 'ses-2']:
        shell_cmd = "sbatch --array={}-{}%{} {} {} {}".format(start, finish, 
                                                   batch_size, bash_file, file_ext, session)
        sp.run(shell_cmd, shell=True)
        print('[INFO] submitted: ', shell_cmd)


        #for sub_num in subject_set:
            #shell_cmd = "sbatch --array={}%1 {}".format(sub_num, bash_file)
            #os.system(shell_cmd)
            #print(shell_cmd)

# %%
run_bash=True
start=1
finish=170
batch_size=150
file_ext="ses-1_task-training_19contrasts.fsf"
session="ses-1"
run_slurm(start, finish, batch_size, session, file_ext)
# Out:
# [INFO] submitted:  sbatch --array=1-170%150 /projects/niblab/experiments/bbx/code/preprocessing/fsl_feat2/feat2.job ses-1_task-training_19contrasts.fsf ses-1

# %%
# run individual batch jobs
submission_list=sub_ids
for x in submission_list[1:]:
    x=x.split("-")[1].lstrip('0')
    start=x
    finish=x
    batch_size=1
    session="ses-1"

    run_slurm(start, finish, batch_size, session, file_ext)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# ## Quality Check

# %%
#get good files ct
s1_subjects_good=[x.split('/')[-4].split("_")[0] for x in glob.glob('/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-*/ses-1/fsl_feat2/*19contrasts.gfeat/cope1.feat/stats/cope1.nii.gz')]
session1_feat2=glob.glob('/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/sub-*/ses-1/fsl_feat2/*19contrasts.gfeat')
s1_subjects_good.sort()                


# get feats
#session1_feat2=glob.glob(
 #   '/projects/niblab/experiments/bbx/data/preprocessed/sub-*/ses-1/fsl_feat2/sub-*.gfeat')

#get good files ct
#s2_subjects_good=[x.split('/')[-4].split("_")[0] for x in glob.glob('/projects/niblab/experiments/bbx/data/preprocessed/sub-*/ses-2/fsl_feat2/*.gfeat/cope1.feat/stats/cope1.nii.gz')]
#session2_feat2=glob.glob('/projects/niblab/experiments/bbx/data/preprocessed/sub-*/ses-2/fsl_feat2/*.gfeat/cope1.feat/stats/cope1.nii.gz')
#s2_subjects_good.sort()                



# get feats
#session2_feat2=glob.glob(
 #   '/projects/niblab/experiments/bbx/data/preprocessed/sub-*/ses-2/fsl_feat2/sub-*.gfeat')




print('\n[SESSION1] %s feat2 folders found'%len(session1_feat2))                     
print('[SESSION1] %s subjects found for feat3'%len(s1_subjects_good))
#print('\n[SESSION2] %s feat2 folders found'%len(session2_feat2))                     
#print('[SESSION2] %s subjects found for feat3'%len(s2_subjects_good))
# Out:
# [SESSION1] 149 feat2 folders found
# [SESSION1] 148 subjects found for feat3

# %%
class BBXFeat2Reports:
    
    def __init__(self):
        self.data_path='/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed'
        
    def feat2_qc(self, tag, sess):
        feat2_dict={}
        feat2=glob.glob(os.path.join(self.data_path,'sub-*/%s/fsl_feat2/*%s.gfeat'%(sess,tag)))
        feat2.sort()

        for feat2_folder in feat2:

            subject=feat2_folder.split("/")[-4].split("_")[0]

            if subject not in feat2_dict:
                feat2_dict[subject]={}

            # collect data files count
            copes=glob.glob(os.path.join(feat2_folder,"cope*/stats/cope1.nii.gz"))
            zstats=glob.glob(os.path.join(feat2_folder, 'cope*/stats/zstat1.nii.gz'))

            copes.sort()
            zstats.sort()

            feat2_dict[subject]['cope_ct']=len(copes)
            feat2_dict[subject]['zstat_ct']=len(zstats)


            """for cope in copes:
                cope_id=cope.split("/")[-1].split(".")[0]

                cope_file=os.path.join(cope, 'stats/cope1.nii.gz')
                #zstats=glob.glob(os.path.join(cope, "stats/zstat1.nii.gz"))
                cp_ct+=1
                # get activation
                cmd_out= sp.check_output(["fslstats", cope_file, '-M'])
                cmd_out=cmd_out.decode("utf-8")

                feat2_dict[subject]["%s_file_mean"%(cope_id)]=cmd_out.strip('\n')
                #feat2_dict[subject]['%s_ct'%cope_id]=len(zstats)"""




        #print(feat2_dict)        
        feat2_df=pd.DataFrame(feat2_dict).T

        return feat2_df;

# %%
obj=BBXFeat2Reports()

# %%
s1_f2=obj.feat2_qc('19contrasts', 'ses-1' )
s1_f2.sort_index(inplace=True)

s1_feat2_m1[s1_feat2_m1.notnull().all(axis=1)]

# %%
s1_f2.head()
# Out:
#          cope_ct  zstat_ct
# sub-001       19        19
# sub-002       19        19
# sub-003       19        19
# sub-004       19        19
# sub-005       19        19

# %% [markdown]
# **What subjects are missing cope folders?**

# %%
s1_f2[s1_f2['cope_ct']<19]
# Out:
#          cope_ct  zstat_ct
# sub-091        0         0

# %%
len(s1_f2.index.values)
# Out:
# 149

# %%
print(s1_f2.index.values)
# Out:
# ['sub-001' 'sub-002' 'sub-003' 'sub-004' 'sub-005' 'sub-006' 'sub-007'
#  'sub-008' 'sub-009' 'sub-010' 'sub-011' 'sub-012' 'sub-013' 'sub-014'
#  'sub-015' 'sub-016' 'sub-017' 'sub-018' 'sub-019' 'sub-020' 'sub-021'
#  'sub-022' 'sub-023' 'sub-024' 'sub-025' 'sub-026' 'sub-027' 'sub-028'
#  'sub-030' 'sub-031' 'sub-032' 'sub-033' 'sub-034' 'sub-035' 'sub-036'
#  'sub-037' 'sub-038' 'sub-039' 'sub-040' 'sub-041' 'sub-042' 'sub-043'
#  'sub-044' 'sub-045' 'sub-046' 'sub-048' 'sub-050' 'sub-051' 'sub-052'
#  'sub-053' 'sub-054' 'sub-055' 'sub-056' 'sub-057' 'sub-058' 'sub-059'
#  'sub-060' 'sub-061' 'sub-062' 'sub-063' 'sub-064' 'sub-065' 'sub-066'
#  'sub-067' 'sub-068' 'sub-070' 'sub-071' 'sub-072' 'sub-073' 'sub-075'
#  'sub-076' 'sub-077' 'sub-078' 'sub-079' 'sub-080' 'sub-082' 'sub-083'
#  'sub-084' 'sub-085' 'sub-086' 'sub-087' 'sub-088' 'sub-089' 'sub-090'
#  'sub-091' 'sub-092' 'sub-093' 'sub-095' 'sub-096' 'sub-097' 'sub-098'
#  'sub-099' 'sub-100' 'sub-102' 'sub-103' 'sub-104' 'sub-107' 'sub-109'
#  'sub-111' 'sub-112' 'sub-114' 'sub-115' 'sub-116' 'sub-117' 'sub-118'
#  'sub-119' 'sub-120' 'sub-121' 'sub-123' 'sub-124' 'sub-128' 'sub-129'
#  'sub-130' 'sub-131' 'sub-132' 'sub-133' 'sub-134' 'sub-135' 'sub-136'
#  'sub-137' 'sub-138' 'sub-140' 'sub-141' 'sub-142' 'sub-143' 'sub-144'
#  'sub-145' 'sub-146' 'sub-147' 'sub-148' 'sub-149' 'sub-150' 'sub-151'
#  'sub-152' 'sub-153' 'sub-154' 'sub-156' 'sub-157' 'sub-159' 'sub-160'
#  'sub-161' 'sub-162' 'sub-163' 'sub-164' 'sub-166' 'sub-167' 'sub-168'
#  'sub-169' 'sub-170']

# %% [markdown]
# ---

# %%
study_path
# Out:
# '/projects/niblab/experiments/bbx'

# %%
datapath='/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed'

# %% [markdown]
# ### Plot model brains

# %%
def plot_feat2( cope,sess,ext):
    
    filepath=os.path.join(study_path, 'data/preprocessed', 
                        'subs_trimmed/sub-*/%s/fsl_feat2/*%s.gfeat/%s.feat/stats/tstat1.nii.gz'%(sess, ext, cope))
    
    
    nrows=10
    ncols=5
    
    tmaps=glob.glob(filepath)
    tmaps.sort()
    
    
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,15))
                    
    for midx, tmap in enumerate(tmaps[:50]):

        settings=axes[int(midx / ncols), int(midx % ncols)]

        #print(int(midx / nrows) ,int(midx % nrows))
        
        sub=tmap.split("/")[-7]

        title_str="%s %s"%(sub, cope)

        plotting.plot_glass_brain(tmap, colorbar=False, threshold=2.0, cmap='viridis',
                          axes=settings,
                          plot_abs=False, display_mode='z', title=title_str) 

    fig.suptitle('subjects tmap taste network')
    plotting.show()

# %%
from nilearn import plotting
from scipy.stats import norm
plot_feat2( 'cope1', 'ses-1','19contrasts')

# %%
def plot_feat2( sub,sess,ext):
    
    filepath=os.path.join(study_path, 'data/preprocessed', 
                        'subs_trimmed/%s/%s/fsl_feat2/*%s.gfeat/cope*.feat/stats/tstat1.nii.gz'%(sub, sess, ext))
    
    
    nrows=4
    ncols=5
    
    tmaps=glob.glob(filepath)
    tmaps.sort()
    
    
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,15))
                    
    for midx, tmap in enumerate(tmaps):

        settings=axes[int(midx / ncols), int(midx % ncols)]

        #print(int(midx / nrows) ,int(midx % nrows))
        
        sub=tmap.split("/")[-7]
        cope=tmap.split("/")[-3].split('.')[0]
        
        title_str="%s %s"%(sub, cope)

        plotting.plot_glass_brain(tmap, colorbar=False, threshold=2.0, cmap='viridis',
                          axes=settings,
                          plot_abs=False, display_mode='z', title=title_str) 

    fig.suptitle('subjects tmap taste network')
    plotting.show()

# %%
from nilearn import plotting
from scipy.stats import norm
plot_feat2( 'sub-001', 'ses-1','19contrasts')

# %% [markdown]
# ### Interactive View

# %%
def interactive_zstat(sub_id='sub-001', sess="ses-1", cope='cope1'):
    
    print("[INFO] viewing report for %s"%sub_id)
    try:
        stat_img='/projects/niblab/experiments/bbx/data/preprocessed/subs_trimmed/%s/%s/fsl_feat2/%s_%s_task-training_19contrasts.gfeat/%s.feat/stats/zstat1.nii.gz'%(sub_id, sess, sub_id, sess, cope)

        #print(stat_img)

        view = plotting.view_img(stat_img, threshold=3)
        # In a Jupyter notebook, if ``view`` is the output of a cell, it will
        # be displayed below the cell
        display(view)
    except: print('[INFO] ERROR NO DATA FOUND')

# %%
cope_ids=['cope1', 'cope2', 'cope3', 'cope4', 'cope5', 'cope6', 'cope7',
          'cope8', 'cope9', 'cope10', 'cope11', 'cope12', 'cope13', 'cope14',
          'cope15', 'cope16', 'cope17', 'cope18', 'cope19']

sessions=['ses-1', 'ses-2']

# %%
sub_ids.sort()
w= widgets.Select(options=sub_ids)
widgets.interactive(interactive_zstat, sub_id=sub_ids, sess=sessions, cope=cope_ids)
# Out:
# interactive(children=(Dropdown(description='sub_id', options=('sub-001', 'sub-002', 'sub-003', 'sub-004', 'sub…

# %% [markdown]
# ---

# %% [markdown]
# ## Write Files

# %%
path='/projects/niblab/experiments/bbx/data/quality_analysis/bbx-trimmed_report.xlsx'

# %%
writer = pd.ExcelWriter(path, engine = 'openpyxl')
book = load_workbook(path)
writer.book = book
s1_feat2_df.to_excel(writer, sheet_name="ses-1_feat2")
#s2_df.to_excel(writer, sheet_name="ses-2_fmriprep")
writer.save()
writer.close()

# %%
new_excel=pd.read_excel(path, sheet_name="ses-1_feat2")

# %%
new_excel.head()
# Out:
#      patID  cope1_file_mean  cope10_file_mean  cope11_file_mean  \
# 0  sub-001        44.340935         14.681960         -1.533675
# 1  sub-002              NaN               NaN               NaN
# 2  sub-003         3.118610          4.323375         -5.581186
# 3  sub-004       -11.824419          8.145715         -0.258319
# 4  sub-005        17.574096         13.734457         -0.735117
#
#    cope12_file_mean  cope13_file_mean  cope14_file_mean  cope15_file_mean  \
# 0          2.466450         -3.958974         -5.316810         -1.469288
# 1               NaN               NaN               NaN               NaN
# 2         -5.068729         -0.533282         -1.856489         -1.304627
# 3         -0.977200          0.578949          0.955398          0.499258
# 4         -1.386533          0.719741          0.535465         -0.155293
#
#    cope16_file_mean  cope2_file_mean  cope3_file_mean  cope4_file_mean  \
# 0          3.637115        13.566539         6.302807        -2.799149
# 1               NaN              NaN              NaN              NaN
# 2         -3.664009         6.508589        16.016069        -3.393638
# 3         -1.307650         9.228001         4.539375         0.820934
# 4         -1.273557        17.729505        16.246499         3.371434
#
#    cope5_file_mean  cope6_file_mean  cope7_file_mean  cope8_file_mean  \
# 0         1.309076         2.952328        -1.032742        37.124886
# 1              NaN              NaN              NaN              NaN
# 2        -2.847613        -1.507653         2.195529       -12.749093
# 3         0.144360         0.021328         1.121939       -16.810584
# 4         2.690698         2.774878         4.052780         1.822865
#
#    cope9_file_mean  cope_ct
# 0         6.628213       16
# 1              NaN        0
# 2        -9.375297       16
# 3         4.204770       16
# 4         1.850203       16

# %% [markdown]
# ---
